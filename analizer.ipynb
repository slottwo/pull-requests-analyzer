# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
analyses = [pd.read_csv("analyses_per_repository/"+filepath) for filepath in os.listdir('analyses_per_repository')]

# %%
total_analysis = pd.read_csv("total_analysis.csv")

# %%
pd.plotting.boxplot(total_analysis)
# Out:
# <AxesSubplot:>

# %%
total = pd.DataFrame(total_analysis.sum())

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     229         if use_numexpr:
# --> 230             return _evaluate(op, op_str, a, b)  # type: ignore
#     231     return _evaluate_standard(op, op_str, a, b)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# ...

# %%
total.loc[['total_merges', 'total_rebases', 'total_unknown', 'total_not_merged_pull_requests']].plot.bar()
# Out:
# <AxesSubplot:>
